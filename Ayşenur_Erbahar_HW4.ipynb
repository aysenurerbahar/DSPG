# %% [markdown]
# Amazon Top 50 Bestselling Books 2009 - 2019

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/bestsellers with categories.csv')

# %%
df.head()
# Out:
#                                                 Name  ...        Genre
# 0                      10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                  11/22/63: A Novel  ...      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                             1984 (Signet Classics)  ...      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df.tail()
# Out:
#                                                   Name  ...        Genre
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [5 rows x 7 columns]

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df.shape
# Out:
# (550, 7)

# %%
pd.set_option("display.max_columns", df.shape[1])

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df["Author"]
# Out:
# 0                      JJ Smith
# 1                  Stephen King
# 2            Jordan B. Peterson
# 3                 George Orwell
# 4      National Geographic Kids
#                  ...
# 545                 Jeff Kinney
# 546                 Jen Sincero
# 547                 Jen Sincero
# 548                 Jen Sincero
# 549                 Jen Sincero
# Name: Author, Length: 550, dtype: object

# %%
df.Author
# Out:
# 0                      JJ Smith
# 1                  Stephen King
# 2            Jordan B. Peterson
# 3                 George Orwell
# 4      National Geographic Kids
#                  ...
# 545                 Jeff Kinney
# 546                 Jen Sincero
# 547                 Jen Sincero
# 548                 Jen Sincero
# 549                 Jen Sincero
# Name: Author, Length: 550, dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df.iloc[2]
# Out:
# Name           12 Rules for Life: An Antidote to Chaos
# Author                              Jordan B. Peterson
# User Rating                                        4.7
# Reviews                                          18979
# Price                                               15
# Year                                              2018
# Genre                                      Non Fiction
# Name: 2, dtype: object

# %%
df.iloc[[0,2,6]]
# Out:
#                                                 Name               Author  \
# 0                      10-Day Green Smoothie Cleanse             JJ Smith
# 2            12 Rules for Life: An Antidote to Chaos   Jordan B. Peterson
# 6  A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
#
#    User Rating  Reviews  Price  Year        Genre
# 0          4.7    17350      8  2016  Non Fiction
# 2          4.7    18979     15  2018  Non Fiction
# 6          4.7    19735     30  2014      Fiction

# %%
df.loc[[0,2], "Price"]
# Out:
# 0     8
# 2    15
# Name: Price, dtype: int64

# %%
df.loc[[0,2,5], ["Name", "Author"]]
# Out:
#                                             Name               Author
# 0                  10-Day Green Smoothie Cleanse             JJ Smith
# 2        12 Rules for Life: An Antidote to Chaos   Jordan B. Peterson
# 5  A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin

# %%
df.loc[0:8, "Name":"Price"]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
#
#                      Author  User Rating  Reviews  Price
# 0                  JJ Smith          4.7    17350      8
# 1              Stephen King          4.6     2052     22
# 2        Jordan B. Peterson          4.7    18979     15
# 3             George Orwell          4.7    21424      6
# 4  National Geographic Kids          4.8     7665     12
# 5       George R. R. Martin          4.4    12643     11
# ...

# %%
df.loc[200, "Name"]
# Out:
# "Killing Patton: The Strange Death of World War II's Most Audacious General (Bill O'Reilly's Killing Series)"

# %%
df.loc[200, ["Name", "Author"]]
# Out:
# Name      Killing Patton: The Strange Death of World War...
# Author                                        Bill O'Reilly
# Name: 200, dtype: object

# %%
df.set_index('User Rating',inplace=True)

# %%
df
# Out:
#                                                           Name  \
# User Rating
# 4.7                              10-Day Green Smoothie Cleanse
# 4.6                                          11/22/63: A Novel
# 4.7                    12 Rules for Life: An Antidote to Chaos
# 4.7                                     1984 (Signet Classics)
# 4.8          5,000 Awesome Facts (About Everything!) (Natio...
# ...                                                        ...
# 4.9               Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 4.7          You Are a Badass: How to Stop Doubting Your Gr...
# 4.7          You Are a Badass: How to Stop Doubting Your Gr...
# 4.7          You Are a Badass: How to Stop Doubting Your Gr...
# 4.7          You Are a Badass: How to Stop Doubting Your Gr...
#
#                                Author  Reviews  Price  Year        Genre
# User Rating
# 4.7                          JJ Smith    17350      8  2016  Non Fiction
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      User Rating                                               Name  \
# 0            4.7                      10-Day Green Smoothie Cleanse
# 1            4.6                                  11/22/63: A Novel
# 2            4.7            12 Rules for Life: An Antidote to Chaos
# 3            4.7                             1984 (Signet Classics)
# 4            4.8  5,000 Awesome Facts (About Everything!) (Natio...
# ..           ...                                                ...
# 545          4.9       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 547          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 548          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 549          4.7  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  Reviews  Price  Year        Genre
# 0                    JJ Smith    17350      8  2016  Non Fiction
# ...

# %%
df.sort_index(ascending=False)
# Out:
#      User Rating                                               Name  \
# 549          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 548          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 547          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 546          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 545          4.9       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# ..           ...                                                ...
# 4            4.8  5,000 Awesome Facts (About Everything!) (Natio...
# 3            4.7                             1984 (Signet Classics)
# 2            4.7            12 Rules for Life: An Antidote to Chaos
# 1            4.6                                  11/22/63: A Novel
# 0            4.7                      10-Day Green Smoothie Cleanse
#
#                        Author  Reviews  Price  Year        Genre
# 549               Jen Sincero    14331      8  2019  Non Fiction
# ...

# %%
df.reset_index(inplace=True)

# %%
filt = (df["Genre"] == "Fiction")

# %%
df[filt]
# Out:
#      index  User Rating                                               Name  \
# 1        1          4.6                                  11/22/63: A Novel
# 3        3          4.7                             1984 (Signet Classics)
# 5        5          4.4      A Dance with Dragons (A Song of Ice and Fire)
# 6        6          4.7  A Game of Thrones / A Clash of Kings / A Storm...
# 7        7          4.7                     A Gentleman in Moscow: A Novel
# ..     ...          ...                                                ...
# 541    541          4.8                                             Wonder
# 542    542          4.8                                             Wonder
# 543    543          4.8                                             Wonder
# 544    544          4.8                                             Wonder
# 545    545          4.9       Wrecking Ball (Diary of a Wimpy Kid Book 14)
#
#      ... Price  Year    Genre
# 1    ...    22  2011  Fiction
# ...

# %%
filt = (df["Author"] == "JJ Smith") & (df["Genre"] == "Non Fiction")

# %%
df[filt]
# Out:
#    index  User Rating                           Name  ... Price  Year  \
# 0      0          4.7  10-Day Green Smoothie Cleanse  ...     8  2016
#
#          Genre
# 0  Non Fiction
#
# [1 rows x 8 columns]

# %%
df.loc[~filt]
# Out:
#      index  User Rating                                               Name  \
# 1        1          4.6                                  11/22/63: A Novel
# 2        2          4.7            12 Rules for Life: An Antidote to Chaos
# 3        3          4.7                             1984 (Signet Classics)
# 4        4          4.8  5,000 Awesome Facts (About Everything!) (Natio...
# 5        5          4.4      A Dance with Dragons (A Song of Ice and Fire)
# ..     ...          ...                                                ...
# 545    545          4.9       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    546          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 547    547          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 548    548          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 549    549          4.7  You Are a Badass: How to Stop Doubting Your Gr...
#
#      ... Price  Year        Genre
# ...

# %%
high_price = (df["Price"] > 30)

# %%
df.loc[high_price]
# Out:
#      index  User Rating                                               Name  \
# 12      12          4.6                            A Stolen Life: A Memoir
# 69      69          4.5  Diagnostic and Statistical Manual of Mental Di...
# 70      70          4.5  Diagnostic and Statistical Manual of Mental Di...
# 108    108          4.5  Fifty Shades Trilogy (Fifty Shades of Grey / F...
# 151    151          4.9                           Hamilton: The Revolution
# 159    159          4.8         Harry Potter Paperback Box Set (Books 1-7)
# 271    271          4.5  Publication Manual of the American Psychologic...
# 272    272          4.5  Publication Manual of the American Psychologic...
# 273    273          4.5  Publication Manual of the American Psychologic...
# 274    274          4.5  Publication Manual of the American Psychologic...
# 275    275          4.5  Publication Manual of the American Psychologic...
# ...

# %%
df.loc[high_price, ["Name", "Author", "Reviews"]]
# Out:
#                                                   Name  \
# 12                             A Stolen Life: A Memoir
# 69   Diagnostic and Statistical Manual of Mental Di...
# 70   Diagnostic and Statistical Manual of Mental Di...
# 108  Fifty Shades Trilogy (Fifty Shades of Grey / F...
# 151                           Hamilton: The Revolution
# 159         Harry Potter Paperback Box Set (Books 1-7)
# 271  Publication Manual of the American Psychologic...
# 272  Publication Manual of the American Psychologic...
# 273  Publication Manual of the American Psychologic...
# 274  Publication Manual of the American Psychologic...
# 275  Publication Manual of the American Psychologic...
# 276  Publication Manual of the American Psychologic...
# 277  Publication Manual of the American Psychologic...
# 278  Publication Manual of the American Psychologic...
# 279  Publication Manual of the American Psychologic...
# 280  Publication Manual of the American Psychologic...
# ...

# %%
filt
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# Length: 550, dtype: bool

# %%
df["Name"].apply(len)
# Out:
# 0      29
# 1      17
# 2      39
# 3      22
# 4      66
#        ..
# 545    44
# 546    86
# 547    86
# 548    86
# 549    86
# Name: Name, Length: 550, dtype: int64

# %%
df.loc[:,["Price","User Rating"]].apply(lambda x: x.max())
# Out:
# Price          105.0
# User Rating      4.9
# dtype: float64

# %%
df["Price"].nlargest(5)
# Out:
# 69     105
# 70     105
# 473     82
# 151     54
# 346     53
# Name: Price, dtype: int64

# %%
df.nlargest(5, "Price")
# Out:
#      index  User Rating                                               Name  \
# 69      69          4.5  Diagnostic and Statistical Manual of Mental Di...
# 70      70          4.5  Diagnostic and Statistical Manual of Mental Di...
# 473    473          4.7                       The Twilight Saga Collection
# 151    151          4.9                           Hamilton: The Revolution
# 346    346          4.7  The Book of Basketball: The NBA According to T...
#
#      ... Price  Year        Genre
# 69   ...   105  2013  Non Fiction
# 70   ...   105  2014  Non Fiction
# 473  ...    82  2009      Fiction
# 151  ...    54  2016  Non Fiction
# 346  ...    53  2009  Non Fiction
#
# [5 rows x 8 columns]

# %%
df.nsmallest(5, "User Rating")
# Out:
#      index  User Rating                                               Name  \
# 353    353          3.3                                 The Casual Vacancy
# 132    132          3.6                         Go Set a Watchman: A Novel
# 106    106          3.8  Fifty Shades of Grey: Book One of the Fifty Sh...
# 107    107          3.8  Fifty Shades of Grey: Book One of the Fifty Sh...
# 22      22          3.9                                          Allegiant
#
#      ... Price  Year    Genre
# 353  ...    12  2012  Fiction
# 132  ...    19  2015  Fiction
# 106  ...    14  2012  Fiction
# 107  ...    14  2013  Fiction
# 22   ...    13  2013  Fiction
#
# [5 rows x 8 columns]

# %%
df.median()
# Out:
# index           274.5
# User Rating       4.7
# Reviews        8580.0
# Price            11.0
# Year           2014.0
# dtype: float64

# %%
df.count()
# Out:
# index          550
# User Rating    550
# Name           550
# Author         550
# Reviews        550
# Price          550
# Year           550
# Genre          550
# dtype: int64

# %%
df["Year"].value_counts()
# Out:
# 2019    50
# 2018    50
# 2017    50
# 2016    50
# 2015    50
# 2014    50
# 2013    50
# 2012    50
# 2011    50
# 2010    50
# 2009    50
# Name: Year, dtype: int64

# %%
df["Genre"].value_counts()
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %%
df["Author"].value_counts()
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Suzanne Collins                       11
# Rick Riordan                          11
# American Psychological Association    10
#                                       ..
# Eric Larson                            1
# Allie Brosh                            1
# Michael Wolff                          1
# Rob Bell                               1
# Brené Brown                           1
# Name: Author, Length: 248, dtype: int64

# %%
df["User Rating"].value_counts()
# Out:
# 4.8    127
# 4.7    108
# 4.6    105
# 4.5     60
# 4.9     52
# 4.4     38
# 4.3     25
# 4.0     14
# 4.2      8
# 4.1      6
# 3.9      3
# 3.8      2
# 3.3      1
# 3.6      1
# Name: User Rating, dtype: int64

# %%
df.groupby(["Author"])

# %%
author_group = df.groupby(["Author"])

# %%
author_group.get_group("Suzanne Collins")
# Out:
#      index  User Rating                                    Name  ... Price  \
# 46      46          4.7        Catching Fire (The Hunger Games)  ...    11
# 47      47          4.7        Catching Fire (The Hunger Games)  ...    11
# 48      48          4.7        Catching Fire (The Hunger Games)  ...    11
# 236    236          4.5           Mockingjay (The Hunger Games)  ...     8
# 237    237          4.5           Mockingjay (The Hunger Games)  ...     8
# 238    238          4.5           Mockingjay (The Hunger Games)  ...     8
# 407    407          4.7                        The Hunger Games  ...    14
# 408    408          4.7               The Hunger Games (Book 1)  ...     8
# 409    409          4.7               The Hunger Games (Book 1)  ...     8
# 410    410          4.8  The Hunger Games Trilogy Boxed Set (1)  ...    30
# 411    411          4.8  The Hunger Games Trilogy Boxed Set (1)  ...    30
#
#      Year    Genre
# 46   2010  Fiction
# 47   2011  Fiction
# ...

# %%
author_group["User Rating"].value_counts()
# Out:
# Author                      User Rating
# Abraham Verghese            4.6            2
# Adam Gasiewski              4.4            1
# Adam Mansbach               4.8            1
# Adir Levy                   4.8            1
# Admiral William H. McRaven  4.7            1
#                                           ..
# Walter Isaacson             4.5            1
# William Davis               4.4            2
# William P. Young            4.6            2
# Wizards RPG Team            4.8            3
# Zhi Gang Sha                4.6            2
# Name: User Rating, Length: 301, dtype: int64

# %%
author_group["User Rating"].value_counts().loc["Wizards RPG Team"]
# Out:
# User Rating
# 4.8    3
# Name: User Rating, dtype: int64

# %%
author_group["Price"].median()
# Out:
# Author
# Abraham Verghese              11.0
# Adam Gasiewski                 6.0
# Adam Mansbach                  9.0
# Adir Levy                     13.0
# Admiral William H. McRaven    11.0
#                               ...
# Walter Isaacson               20.0
# William Davis                  6.0
# William P. Young               8.0
# Wizards RPG Team              27.0
# Zhi Gang Sha                  11.5
# Name: Price, Length: 248, dtype: float64

# %%
author_group["User Rating"].agg(["median", "mean"])
# Out:
#                             median      mean
# Author
# Abraham Verghese               4.6  4.600000
# Adam Gasiewski                 4.4  4.400000
# Adam Mansbach                  4.8  4.800000
# Adir Levy                      4.8  4.800000
# Admiral William H. McRaven     4.7  4.700000
# ...                            ...       ...
# Walter Isaacson                4.6  4.566667
# William Davis                  4.4  4.400000
# William P. Young               4.6  4.600000
# Wizards RPG Team               4.8  4.800000
# Zhi Gang Sha                   4.6  4.600000
#
# [248 rows x 2 columns]

# %%
df.dropna(axis="columns", how="all")
# Out:
#      index  User Rating                                               Name  \
# 0        0          4.7                      10-Day Green Smoothie Cleanse
# 1        1          4.6                                  11/22/63: A Novel
# 2        2          4.7            12 Rules for Life: An Antidote to Chaos
# 3        3          4.7                             1984 (Signet Classics)
# 4        4          4.8  5,000 Awesome Facts (About Everything!) (Natio...
# ..     ...          ...                                                ...
# 545    545          4.9       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    546          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 547    547          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 548    548          4.7  You Are a Badass: How to Stop Doubting Your Gr...
# 549    549          4.7  You Are a Badass: How to Stop Doubting Your Gr...
#
#      ... Price  Year        Genre
# ...

# %%
#df = df.dropna(axis="columns", inplace=True)

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
